# %% [markdown]
# ![image.png](attachment:2a9ff8ed-c071-4f1d-a9fe-210e16d76fca.png)

# %%
# PROJECT 1A PSEUDOCODE
Begin
Input cart of goods
Review cart of goods
If you want to proceed then,
Make payments
If not, review cart again
Print receipt
End

# %% [markdown]
# ![image.png](attachment:a12ea41b-c7f2-4c6f-98d3-d23a2b55034b.png)

# %%
Begin
Input first name a
Input second name b
Input age for a age1
Input age for b age2
Let temp = age1
Let age1 = age2
Let age2 = temp
End
