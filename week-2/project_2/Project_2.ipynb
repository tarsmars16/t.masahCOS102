# %%
answer = input("Would you like to calculate roots for Quadratic (A), Cubic (B), or Quartic (C) equation?")

# Quadratic Equation Formula
if answer == "A":
  a = float(input("What is the value of A: "))
  b = float(input("What is the value of B: "))
  c = float(input("What is the value of C: "))

  d = b**2 - 4*a*c
  for x in range (-100,101):
    if b**2 - 4*a*c == 0:
      print("Possible Roots = ")
# Out:
# Would you like to calculate roots for Quadratic (A), Cubic (B), or Quartic (C) equation? A
# What is the value of A:  1
# What is the value of B:  7
# What is the value of C:  6
