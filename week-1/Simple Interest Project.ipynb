# %%
# Program to Calculate Simple Interest
p = float(input("Enter the Amount for Principal: "))
n = float(input("Enter number of times interest is compounded per year: "))
r = float(input("Enter the interest rate: "))
t = float(input("Enter the number of years: "))


a = p * (1 + (r/n)) ** (n*t)

print("The Accumulated Amount is =N", a)
# Out:
# Enter the Amount for Principal:  324.23
# Enter the number of compounding periods per year:  4
# Enter the interest rate:  4
# Enter the number of years:  2
# The Accumulated Amount is =N 83002.88

# %% [markdown]
# ![image.png](attachment:1152a1dc-780e-4eaa-a5c8-c5f179d19d8e.png)

# %% [markdown]
# ###
