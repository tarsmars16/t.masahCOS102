# %% [markdown]
# # Annuity Plan Program
#
# pmt = float(input("Enter payment per period: "))
# r = float(input("Enter interest rate: "))
# n = float(input("Enter number of times interest is compounded per year: "))
# t = float(input("Enter number of years: "))
#
# a = pmt * (((( 1 + (r/n)) ** (n*t)) - 1 ) / (r*n))
#
# print("The future value of the annuity is =N", a)

# %% [markdown]
# ![image.png](attachment:cfe80f58-ed80-4d2d-ad83-402cda1dc001.png)
